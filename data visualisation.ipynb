# %%
import numpy as np

# %%
import pandas as pd
import seaborn as sns

# %%
# %matplotlib inline

# %%
df1=pd.read_csv('/Users/anusha/Downloads/banknotes.csv',index_col=0)

# %%
df1
# Out:
#             Length   Left  Right  Bottom   Top  Diagonal
# conterfeit
# 0            214.8  131.0  131.1     9.0   9.7     141.0
# 0            214.6  129.7  129.7     8.1   9.5     141.7
# 0            214.8  129.7  129.7     8.7   9.6     142.2
# 0            214.8  129.7  129.6     7.5  10.4     142.0
# 0            215.0  129.6  129.7    10.4   7.7     141.8
# ...            ...    ...    ...     ...   ...       ...
# 1            215.0  130.4  130.3     9.9  12.1     139.6
# 1            215.1  130.3  129.9    10.3  11.5     139.7
# 1            214.8  130.3  130.4    10.6  11.1     140.0
# 1            214.7  130.7  130.8    11.2  11.2     139.4
# 1            214.3  129.9  129.9    10.2  11.5     139.6
#
# [200 rows x 6 columns]

# %%
df1.head()
# Out:
#             Length   Left  Right  Bottom   Top  Diagonal
# conterfeit
# 0            214.8  131.0  131.1     9.0   9.7     141.0
# 0            214.6  129.7  129.7     8.1   9.5     141.7
# 0            214.8  129.7  129.7     8.7   9.6     142.2
# 0            214.8  129.7  129.6     7.5  10.4     142.0
# 0            215.0  129.6  129.7    10.4   7.7     141.8

# %%
df2=pd.read_csv('/Users/anusha/Downloads/banklist.csv',encoding='unicode_escape')

# %%
df2
# Out:
#                             Bank Name               City  State   Cert   \
# 0                       Signature Bank           New York     NY  57053
# 1                  Silicon Valley Bank        Santa Clara     CA  24735
# 2                    Almena State Bank             Almena     KS  15426
# 3           First City Bank of Florida  Fort Walton Beach     FL  16748
# 4                 The First State Bank      Barboursville     WV  14361
# ..                                 ...                ...    ...    ...
# 560                 Superior Bank, FSB           Hinsdale     IL  32646
# 561                Malta National Bank              Malta     OH   6629
# 562    First Alliance Bank & Trust Co.         Manchester     NH  34264
# 563  National State Bank of Metropolis         Metropolis     IL   3815
# 564                   Bank of Honolulu           Honolulu     HI  21029
#
#                   Acquiring Institution  Closing Date    Fund
# ...

# %%
df2.head()
# Out:
#                    Bank Name               City  State   Cert   \
# 0              Signature Bank           New York     NY  57053
# 1         Silicon Valley Bank        Santa Clara     CA  24735
# 2           Almena State Bank             Almena     KS  15426
# 3  First City Bank of Florida  Fort Walton Beach     FL  16748
# 4        The First State Bank      Barboursville     WV  14361
#
#                 Acquiring Institution  Closing Date    Fund
# 0                  Flagstar Bank, N.A.     12-Mar-23  10540
# 1  FirstCitizens Bank & Trust Company     10-Mar-23  10539
# 2                          Equity Bank     23-Oct-20  10538
# 3            United Fidelity Bank, fsb     16-Oct-20  10537
# 4                       MVB Bank, Inc.      3-Apr-20  10536

# %%
df1['Length'].hist(bins=30)
# Out:
# <AxesSubplot:>

# %%
df1['Length'].plot(kind='hist',bins=20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df2.plot.area()
# Out:
# <AxesSubplot:>

# %%
df1.plot.area()
# Out:
# <AxesSubplot:xlabel='conterfeit'>

# %%
df1.plot.area(alpha=0.5)
# Out:
# <AxesSubplot:xlabel='conterfeit'>

# %%
df1.plot.bar()
# Out:
# <AxesSubplot:xlabel='conterfeit'>

# %%
df1.plot.bar(stacked=True)
# Out:
# <AxesSubplot:xlabel='conterfeit'>

# %%
df1.plot.line()
# Out:
# <AxesSubplot:xlabel='conterfeit'>

# %%
df1.plot.scatter(x='Length',y='Top',c='Left',cmap='coolwarm')
# Out:
# <AxesSubplot:xlabel='Length', ylabel='Top'>

# %%
df1.plot.box()
# Out:
# <AxesSubplot:>

# %%
df=pd.DataFrame(np.random.randn(1000,2),columns=['a','b'])

# %%
df
# Out:
#             a         b
# 0    0.478114 -0.291952
# 1    0.080546 -1.149718
# 2    0.041073  2.560383
# 3   -0.403321  0.007647
# 4   -0.071154  0.380265
# ..        ...       ...
# 995 -1.279620  0.467104
# 996 -0.383362 -2.643569
# 997  0.072279  1.354913
# 998  0.003160  1.744313
# 999  1.394223 -0.596867
#
# [1000 rows x 2 columns]

# %%
df.head()
# Out:
#           a         b
# 0  0.478114 -0.291952
# 1  0.080546 -1.149718
# 2  0.041073  2.560383
# 3 -0.403321  0.007647
# 4 -0.071154  0.380265

# %%
df.plot.hexbin(x='a',y='b',gridsize=25)
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
df1['Left'].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df1['Left'].plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# # plotpy/cufflinks

# %%
import numpy as np
import pandas as pd

# %%
from platform import python_version
print(python_version())
# Out:
# 3.9.13

# %%
import cufflinks as cf

# %%
pip install cufflinks --upgrade
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from plotly.offline import download_plotlyjs, init_notebook_mode,plot,iplot

# %%
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
import pandas as pds
import numpy as npy
from plotly import tools
import plotly.offline as offline
import plotly.graph_objs as go

from plotly import __version__

from plotly.offline import download_plotlyjs,init_notebook_mode,plot,iplot

import cufflinks as cl

# %%
# !{sys.executable} -m pip install cufflinks
# Out:
# zsh:1: parse error near `-m'

# %%
df=pd.DataFrame(np.random.randn(100,4),columns='A B C D'.split())

# %%
df.head()
# Out:
#           A         B         C         D
# 0  0.714337  0.183390 -0.210569 -0.781090
# 1  0.258563  1.349790 -1.358423 -0.106890
# 2 -1.761966 -0.013619 -0.002246  0.697561
# 3 -0.968428  1.448960 -0.302378 -0.792761
# 4  1.860793 -1.175955 -0.969573 -1.273032

# %%
df
# Out:
#            A         B         C         D
# 0   0.714337  0.183390 -0.210569 -0.781090
# 1   0.258563  1.349790 -1.358423 -0.106890
# 2  -1.761966 -0.013619 -0.002246  0.697561
# 3  -0.968428  1.448960 -0.302378 -0.792761
# 4   1.860793 -1.175955 -0.969573 -1.273032
# ..       ...       ...       ...       ...
# 95 -0.467985  0.994010 -1.606915 -1.243679
# 96 -0.547088 -0.738039  0.564410 -0.660210
# 97 -0.708278 -0.341122 -0.184025 -1.788044
# 98  0.984149 -1.544473  0.895322  2.041970
# 99  1.082447  0.743066  1.084896 -0.042990
#
# [100 rows x 4 columns]

# %%
df2=pd.DataFrame({'Category': ['a','b','c'],'values': [32,43,56]})

# %%
df2
# Out:
#   Category  values
# 0        a      32
# 1        b      43
# 2        c      56

# %%
df.plot()
# Out:
# <Axes: >

# %%
matplotlib% inline
# Out:
# UsageError: unrecognized arguments: inline

# %%
df.iplot()
# Out:
# <div>                            <div id="905822cc-d7a1-4615-9127-d0067c7691cf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind='scatter',x='A',y='B', mode='markers',size=20)
# Out:
# <div>                            <div id="1f387c23-3a45-4d04-8170-38179bdc9333" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df2.iplot(kind='bar',x='Category',y='values')
# Out:
# <div>                            <div id="f0cbc255-96bc-4a64-8fea-439440f59e86" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind='bar')
# Out:
# <div>                            <div id="eb9f8129-b62f-4623-82e7-d84795834277" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.count().iplot(kind='bar')
# Out:
# <div>                            <div id="7923c07d-2371-49f7-bbb8-1085a73b1bc2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind='box')
# Out:
# <div>                            <div id="2fef7f33-ca3f-4485-b7c9-0dd9f3fd38d2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df3=pd.DataFrame({'x':[1,2,3,4,5],'y':[10,20,30,40,50],'z':[100,200,300,400,500]})

# %%
df3
# Out:
#    x   y    z
# 0  1  10  100
# 1  2  20  200
# 2  3  30  300
# 3  4  40  400
# 4  5  50  500

# %%
df3.iplot(kind='surface', colorscale='rdylbu')
# Out:
# <div>                            <div id="0a1715e8-d3fb-4e0f-914b-f928135eaaaa" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind='hist')
# Out:
# <div>                            <div id="a25b1aa9-5c35-44f7-a17a-56b583b5e611" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df[['A','B']].iplot(kind='spread')
# Out:
# /Users/anusha/opt/anaconda3/lib/python3.9/site-packages/cufflinks/plotlytools.py:849: FutureWarning:
#
# The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead.
#
# /Users/anusha/opt/anaconda3/lib/python3.9/site-packages/cufflinks/plotlytools.py:850: FutureWarning:
#
# The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead.
# <div>                            <div id="dd9fc1a9-3d71-436b-8efa-4d7cf64ebc79" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind='bubble', x='A',y='B',size='C')
# Out:
# <div>                            <div id="6021f9a9-2eba-4634-a508-0a88ad14b86f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.scatter_matrix()
# Out:
# <div>                            <div id="5f8df019-9897-4699-b296-387cc1a0f3eb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# # choropleth

# %%
conda install chart_studio package
# Out:
# ...
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# ...
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
#
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - chart_studio
#   - package
#
# Current channels:
#
#   - https://repo.anaconda.com/pkgs/main/osx-64
#   - https://repo.anaconda.com/pkgs/main/noarch
#   - https://repo.anaconda.com/pkgs/r/osx-64
#   - https://repo.anaconda.com/pkgs/r/noarch
#
# To search for alternate channels that may provide the conda package you're
# looking for, navigate to
#
#     https://anaconda.org
#
# and use the search bar at the top of the page.
#
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install chart-studio
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from chart_studio import plotly

# %%
import plotly.plotly as py

# %%
import plotly.offline as pyoff
import plotly.graph_objs as go
from plotly import graph_objs as go

# %%
import plotly.plotly as py

# %%
# !pip install plotly
from chart_studio import plotly

# %%
conda install plotly.graph_objs._funnel
# Out:
# ...
#
# CondaHTTPError: HTTP 000 CONNECTION FAILED for url <https://repo.anaconda.com/pkgs/main/osx-64/current_repodata.json>
# Elapsed: -
#
# An HTTP error occurred when trying to retrieve this URL.
# HTTP errors are often intermittent, and a simple retry will get you on your way.
#
# If your current network has https://www.anaconda.com blocked, please file
# a support request with your network engineering team.
#
# 'https//repo.anaconda.com/pkgs/main/osx-64'
#
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
 pip install <plotly.graph_objs._funnel>
# Out:
# zsh:1: parse error near `>'
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c conda-forge <plotly.graph_objs._funnel>
# Out:
# zsh:1: parse error near `>'
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda config --append channels conda-forge
# Out:
# ...
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda update --all
# Out:
# ...
#
# CondaHTTPError: HTTP 000 CONNECTION FAILED for url <https://repo.anaconda.com/pkgs/main/osx-64/current_repodata.json>
# Elapsed: -
#
# An HTTP error occurred when trying to retrieve this URL.
# HTTP errors are often intermittent, and a simple retry will get you on your way.
#
# If your current network has https://www.anaconda.com blocked, please file
# a support request with your network engineering team.
#
# 'https//repo.anaconda.com/pkgs/main/osx-64'
#
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install numpy
# Out:
# ...
#
# CondaHTTPError: HTTP 000 CONNECTION FAILED for url <https://repo.anaconda.com/pkgs/main/osx-64/current_repodata.json>
# Elapsed: -
#
# An HTTP error occurred when trying to retrieve this URL.
# HTTP errors are often intermittent, and a simple retry will get you on your way.
#
# If your current network has https://www.anaconda.com blocked, please file
# a support request with your network engineering team.
#
# 'https//repo.anaconda.com/pkgs/main/osx-64'
#
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd

# %%
conda install plotly.graph_objects
# Out:
# ...
#
# CondaHTTPError: HTTP 000 CONNECTION FAILED for url <https://repo.anaconda.com/pkgs/main/osx-64/current_repodata.json>
# Elapsed: -
#
# An HTTP error occurred when trying to retrieve this URL.
# HTTP errors are often intermittent, and a simple retry will get you on your way.
#
# If your current network has https://www.anaconda.com blocked, please file
# a support request with your network engineering team.
#
# 'https//repo.anaconda.com/pkgs/main/osx-64'
#
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import plotly.offline as pyoff
import plotly.graph_objs as go
from plotly import graph_objs as go
 
fig=dict(data=go.Scatter(x=[1,2,3,4],y=[1,4,9,16],mode = "lines+markers"))
pyoff.iplot(fig)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 6
#       3 from plotly import graph_objs as go
#       5 fig=dict(data=go.Scatter(x=[1,2,3,4],y=[1,4,9,16],mode = "lines+markers"))
# ----> 6 pyoff.iplot(fig)
#
# File ~/anaconda3/lib/python3.10/site-packages/plotly/offline/offline.py:363, in iplot(figure_or_data, show_link, link_text, validate, image, filename, image_width, image_height, config, auto_play, animation_opts)
#     360 config.setdefault('linkText', link_text)
#     362 # Get figure
# --> 363 figure = tools.return_figure_from_figure_or_data(figure_or_data, validate)
#     365 # Handle image request
#     366 post_script = build_save_image_post_script(
#     367     image, filename, image_height, image_width, 'iplot')
#
# ...

# %%
data=dict(type='choropleth',
         locations=['az','ca','ny'],
         locationmode=['USA-states'],
         colorscale='Portland',
          text=['text1','text2','text3'],
          z=[1.0,2.0,3.0],
          colorbar= {'title':'colorbar title'})

# %%
data
# Out:
# {'type': 'choropleth',
#  'locations': ['az', 'ca', 'ny'],
#  'locationmode': ['USA-states'],
#  'colorscale': 'Portland',
#  'text': ['text1', 'text2', 'text3'],
#  'z': [1.0, 2.0, 3.0],
#  'colorbar': {'title': 'colorbar title'}}

# %%
layout=dict(geo={'scope':'usa'})

# %%
choromap= go.Figure(data=[data], layout= layout)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 choromap= go.Figure(data=[data], layout= layout)
#
# File ~/anaconda3/lib/python3.10/site-packages/plotly/graph_objs/_figure.py:551, in Figure.__init__(self, data, layout, frames, skip_invalid, **kwargs)
#      16 def __init__(
#      17     self,
#      18     data=None,
#    (...)
#      22     **kwargs
#      23 ):
#      24     """
#      25     Create a new Figure instance
#      26
#    (...)
#     549         is invalid AND skip_invalid is False
#     550     """
# --> 551     super(Figure,
#     552           self).__init__(data, layout, frames, skip_invalid, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/plotly/basedatatypes.py:155, in BaseFigure.__init__(self, data, layout_plotly, frames, skip_invalid, **kwargs)
# ...

# %%
iplot(choromap)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 iplot(choromap)
#
# NameError: name 'iplot' is not defined

# %%
choromap
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 choromap
#
# NameError: name 'choromap' is not defined
